# %% [markdown]
# # Fit data
#
# Fit Gaussian Process model to crime data over London

# %%
import arviz as az
import numpy as np
import pandas as pd
import pymc3 as pm
import theano.tensor as tt
import seaborn as sns

from bokeh.io import output_notebook
from bokeh.models import BoxAnnotation, Label, Legend, Span
from bokeh.palettes import brewer
from bokeh.plotting import figure, show

from calendar import monthrange

# %%
# %config InlineBackend.figure_format = 'retina'
RANDOM_SEED = 8927
np.random.seed(RANDOM_SEED)
az.style.use("arviz-darkgrid")

# %%
df = pd.read_pickle("mps.borough.crime.2010-2021.pickle").rename(columns={'LookUp_BoroughName': 'borough'}).drop('index',axis=1)
df['month'] = pd.DatetimeIndex(df['date']).month
df['year'] = pd.DatetimeIndex(df['date']).year
df
# Out:
#                           MajorText                           MinorText  \
# 0         Arson and Criminal Damage                               Arson
# 1         Arson and Criminal Damage                     Criminal Damage
# 2                          Burglary     Burglary Business and Community
# 3                          Burglary                   Domestic Burglary
# 4                     Drug Offences                    Drug Trafficking
# ...                             ...                                 ...
# 243403             Vehicle Offences          Theft from a Motor Vehicle
# 243404             Vehicle Offences  Theft or Taking of a Motor Vehicle
# 243405  Violence Against the Person                            Homicide
# 243406  Violence Against the Person                Violence with Injury
# 243407  Violence Against the Person             Violence without Injury
#
#                      borough yearmonth  value        date  month  year
# 0       Barking and Dagenham    201004      6  2010-04-01      4  2010
# 1       Barking and Dagenham    201004    208  2010-04-01      4  2010
# 2       Barking and Dagenham    201004     49  2010-04-01      4  2010
# 3       Barking and Dagenham    201004    118  2010-04-01      4  2010
# 4       Barking and Dagenham    201004      9  2010-04-01      4  2010
# ...                      ...       ...    ...         ...    ...   ...
# 243403           Westminster    202203    290  2022-03-01      3  2022
# 243404           Westminster    202203     51  2022-03-01      3  2022
# 243405           Westminster    202203      0  2022-03-01      3  2022
# 243406           Westminster    202203    347  2022-03-01      3  2022
# 243407           Westminster    202203    659  2022-03-01      3  2022
#
# [243408 rows x 8 columns]

# %%
np.unique(df.year)
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        2021, 2022])

# %%
def dates_to_idx(timelist):
    reference_time = pd.to_datetime("2010-01-01").date()
    t = (timelist - reference_time) / pd.Timedelta(365, "D")
    return np.asarray(t)

# Make decimal dates
t = dates_to_idx(df.date.values)

df = df.assign(t=t)
df
# Out:
#                           MajorText                           MinorText  \
# 0         Arson and Criminal Damage                               Arson
# 1         Arson and Criminal Damage                     Criminal Damage
# 2                          Burglary     Burglary Business and Community
# 3                          Burglary                   Domestic Burglary
# 4                     Drug Offences                    Drug Trafficking
# ...                             ...                                 ...
# 243403             Vehicle Offences          Theft from a Motor Vehicle
# 243404             Vehicle Offences  Theft or Taking of a Motor Vehicle
# 243405  Violence Against the Person                            Homicide
# 243406  Violence Against the Person                Violence with Injury
# 243407  Violence Against the Person             Violence without Injury
#
#                      borough yearmonth  value        date  month  year  \
# 0       Barking and Dagenham    201004      6  2010-04-01      4  2010
# 1       Barking and Dagenham    201004    208  2010-04-01      4  2010
# 2       Barking and Dagenham    201004     49  2010-04-01      4  2010
# 3       Barking and Dagenham    201004    118  2010-04-01      4  2010
# 4       Barking and Dagenham    201004      9  2010-04-01      4  2010
# ...                      ...       ...    ...         ...    ...   ...
# 243403           Westminster    202203    290  2022-03-01      3  2022
# 243404           Westminster    202203     51  2022-03-01      3  2022
# 243405           Westminster    202203      0  2022-03-01      3  2022
# 243406           Westminster    202203    347  2022-03-01      3  2022
# 243407           Westminster    202203    659  2022-03-01      3  2022
#
#                 t
# 0        0.246575
# 1        0.246575
# 2        0.246575
# 3        0.246575
# 4        0.246575
# ...           ...
# 243403  12.169863
# 243404  12.169863
# 243405  12.169863
# 243406  12.169863
# 243407  12.169863
#
# [243408 rows x 9 columns]

# %%
df = df.assign(dayinmonth = list(map(lambda x: monthrange(x.year, x.month)[1], df.date)))
df.value / df.dayinmonth
# Out:
# 0          0.200000
# 1          6.933333
# 2          1.633333
# 3          3.933333
# 4          0.300000
#             ...
# 243403     9.354839
# 243404     1.645161
# 243405     0.000000
# 243406    11.193548
# 243407    21.258065
# Length: 243408, dtype: float64

# %%
df.date.values
# Out:
# array([datetime.date(2010, 4, 1), datetime.date(2010, 4, 1),
#        datetime.date(2010, 4, 1), ..., datetime.date(2022, 3, 1),
#        datetime.date(2022, 3, 1), datetime.date(2022, 3, 1)], dtype=object)

# %%
sdf = df[(df.MajorText == 'Public Order Offences') & (df.borough == 'Westminster')]
sdf
# Out:
#                     MajorText  \
# 1700    Public Order Offences
# 1701    Public Order Offences
# 1702    Public Order Offences
# 1703    Public Order Offences
# 3419    Public Order Offences
# ...                       ...
# 241845  Public Order Offences
# 243389  Public Order Offences
# 243390  Public Order Offences
# 243391  Public Order Offences
# 243392  Public Order Offences
#
#                                                 MinorText      borough  \
# 1700    Other Offences Against the State, or Public Order  Westminster
# 1701                        Public Fear Alarm or Distress  Westminster
# 1702    Racially or Religiously Aggravated Public Fear...  Westminster
# 1703                                     Violent Disorder  Westminster
# 3419    Other Offences Against the State, or Public Order  Westminster
# ...                                                   ...          ...
# 241845                                   Violent Disorder  Westminster
# 243389  Other Offences Against the State, or Public Order  Westminster
# 243390                      Public Fear Alarm or Distress  Westminster
# 243391  Racially or Religiously Aggravated Public Fear...  Westminster
# 243392                                   Violent Disorder  Westminster
#
#        yearmonth  value        date  month  year          t  dayinmonth
# 1700      201004     30  2010-04-01      4  2010   0.246575          30
# 1701      201004    109  2010-04-01      4  2010   0.246575          30
# 1702      201004      6  2010-04-01      4  2010   0.246575          30
# 1703      201004      2  2010-04-01      4  2010   0.246575          30
# 3419      201005     27  2010-05-01      5  2010   0.328767          31
# ...          ...    ...         ...    ...   ...        ...         ...
# 241845    202202      0  2022-02-01      2  2022  12.093151          28
# 243389    202203     29  2022-03-01      3  2022  12.169863          31
# 243390    202203    175  2022-03-01      3  2022  12.169863          31
# 243391    202203     90  2022-03-01      3  2022  12.169863          31
# 243392    202203      0  2022-03-01      3  2022  12.169863          31
#
# [576 rows x 10 columns]

# %%
sns.lineplot(data=sdf, x='date', y='value')
# Out:
# <AxesSubplot:xlabel='date', ylabel='value'>

# %% [markdown]
# ## Build GP model

# %%
x = np.linspace(0, 15, 1000)
priors = [
    ("l_pdecay", pm.Gamma.dist(alpha=10, beta=0.075)),
    ("l_psmooth", pm.Gamma.dist(alpha=4, beta=3)),
    ("period", pm.Normal.dist(mu=1.0, sigma=0.05)),
    ("l_med", pm.Gamma.dist(alpha=2, beta=0.75)),
    ("alpha", pm.Gamma.dist(alpha=5, beta=2)),
    ("l_trend", pm.Gamma.dist(alpha=3, beta=0.5)),
    ("l_noise", pm.Gamma.dist(alpha=2, beta=4)),
]

for i, prior in enumerate(priors):
    plt.plot(
        x,
        np.exp(prior[1].logp(x).eval()),
        label=prior[0]
    )

plt.xlim([0, 10])
plt.legend()
plt.show(p)

# %% [markdown]
# * `l_pdecay`: The periodic decay. The smaller this parameter is, the faster the periodicity goes away. I doubt that the seasonality of the crime will be going away any time soon, and there’s no evidence for that in the data. Most of the prior mass is from 60 to >140 years.
#
# * `l_psmooth`: The smoothness of the periodic component. It controls how “sinusoidal” the periodicity is. The plot of the data shows that seasonality is not an exact sine wave, but its not terribly different from one. We use a Gamma whose mode is at one, and doesn’t have too large of a variance, with most of the prior mass from around 0.5 and 2.
#
# * `period`: The period. We put a very strong prior on, the period that is centered at one. R+W fix, since the period is annual.
#
# * `l_med`: This is the lengthscale for the short to medium long variations. This prior has most of its mass below 6 years.
#
# * `alpha`: This is the shape parameter. This prior is centered at 3, since we’re expecting there to be some more variation than could be explained by an exponentiated quadratic.
#
# * `l_trend`: The lengthscale of the long term trend. It has a wide prior with mass on a 2-year scale. Most of the mass is between 2 to 6 years.
#
# * `l_noise`: The lengthscale of the noise covariance. This noise should be very rapid, in the scale of several months to at most a year or two.

# %% [markdown]
# For all of the scale priors we use distributions that shrink the scale towards zero. The seasonal component and the long term trend have the least mass near zero, since they are the largest influences in the data.
#
# * `eta_per`: Scale of the periodic or seasonal component.
#
# * `eta_med`: Scale of the short to medium term component.
#
# * `eta_trend`: Scale of the long term trend.
#
# * `sigma`: Scale of the white noise.
#
# * `eta_noise`: Scale of correlated, short term noise.

# %%
x = np.linspace(0, 4, 5000)
priors = [
    ("eta_per", pm.HalfCauchy.dist(beta=2)),
    ("eta_med", pm.HalfCauchy.dist(beta=1.0)),
    ("eta_trend", pm.HalfCauchy.dist(beta=3),
    ),  # will use beta=2, but 2.2 is visible on plot
    ("sigma", pm.HalfNormal.dist(sigma=0.25)),
    ("eta_noise", pm.HalfNormal.dist(sigma=0.5)),
]

for i, prior in enumerate(priors):
    plt.plot(
        x,
        np.exp(prior[1].logp(x).eval()),
        label=prior[0]
    )

plt.legend()
plt.show()

# %%
# pull out normalized data
t = sdf["t"].values[:, None]
y = sdf["value"].values
y_mean = y.mean()
y_std = y.std()

y_n = (y - y_mean) / y_std

sdf = sdf.assign(y_n=y_n)

# %%
sdf
# Out:
#                     MajorText  \
# 1700    Public Order Offences
# 1701    Public Order Offences
# 1702    Public Order Offences
# 1703    Public Order Offences
# 3419    Public Order Offences
# ...                       ...
# 241845  Public Order Offences
# 243389  Public Order Offences
# 243390  Public Order Offences
# 243391  Public Order Offences
# 243392  Public Order Offences
#
#                                                 MinorText      borough  \
# 1700    Other Offences Against the State, or Public Order  Westminster
# 1701                        Public Fear Alarm or Distress  Westminster
# 1702    Racially or Religiously Aggravated Public Fear...  Westminster
# 1703                                     Violent Disorder  Westminster
# 3419    Other Offences Against the State, or Public Order  Westminster
# ...                                                   ...          ...
# 241845                                   Violent Disorder  Westminster
# 243389  Other Offences Against the State, or Public Order  Westminster
# 243390                      Public Fear Alarm or Distress  Westminster
# 243391  Racially or Religiously Aggravated Public Fear...  Westminster
# 243392                                   Violent Disorder  Westminster
#
#        yearmonth  value        date  month  year          t  dayinmonth  \
# 1700      201004     30  2010-04-01      4  2010   0.246575          30
# 1701      201004    109  2010-04-01      4  2010   0.246575          30
# 1702      201004      6  2010-04-01      4  2010   0.246575          30
# 1703      201004      2  2010-04-01      4  2010   0.246575          30
# 3419      201005     27  2010-05-01      5  2010   0.328767          31
# ...          ...    ...         ...    ...   ...        ...         ...
# 241845    202202      0  2022-02-01      2  2022  12.093151          28
# 243389    202203     29  2022-03-01      3  2022  12.169863          31
# 243390    202203    175  2022-03-01      3  2022  12.169863          31
# 243391    202203     90  2022-03-01      3  2022  12.169863          31
# 243392    202203      0  2022-03-01      3  2022  12.169863          31
#
#              y_n
# 1700   -0.399682
# 1701    0.972931
# 1702   -0.816678
# 1703   -0.886178
# 3419   -0.451807
# ...          ...
# 241845 -0.920928
# 243389 -0.417057
# 243390  2.119672
# 243391  0.642809
# 243392 -0.920928
#
# [576 rows x 11 columns]

# %%
with pm.Model() as model:
    # yearly periodic component x long term trend
    eta_per = pm.HalfCauchy("eta_per", beta=2, testval=1.0)
    l_pdecay = pm.Gamma("l_pdecay", alpha=10, beta=0.075)
    period = pm.Normal("period", mu=1, sigma=0.2)
    l_psmooth = pm.Gamma("l_psmooth ", alpha=4, beta=3)
    cov_seasonal = (eta_per ** 2 * pm.gp.cov.Periodic(1, period, l_psmooth) * pm.gp.cov.Matern52(1, l_pdecay))
    gp_seasonal = pm.gp.Marginal(cov_func=cov_seasonal)

    # small/medium term irregularities
    eta_med = pm.HalfCauchy("eta_med", beta=0.5, testval=0.1)
    l_med = pm.Gamma("l_med", alpha=2, beta=0.75)
    alpha = pm.Gamma("alpha", alpha=5, beta=2)
    cov_medium = eta_med ** 2 * pm.gp.cov.RatQuad(1, l_med, alpha)
    gp_medium = pm.gp.Marginal(cov_func=cov_medium)

    # long term trend
    eta_trend = pm.HalfCauchy("eta_trend", beta=2, testval=2.0)
    l_trend = pm.Gamma("l_trend", alpha=3, beta=0.5)
    cov_trend = eta_trend ** 2 * pm.gp.cov.ExpQuad(1, l_trend)
    gp_trend = pm.gp.Marginal(cov_func=cov_trend)

    # noise model
    eta_noise = pm.HalfNormal("eta_noise", sigma=0.5, testval=0.05)
    l_noise = pm.Gamma("l_noise", alpha=2, beta=4)
    sigma = pm.HalfNormal("sigma", sigma=0.25, testval=0.05)
    cov_noise = eta_noise ** 2 * pm.gp.cov.Matern32(1, l_noise) + pm.gp.cov.WhiteNoise(sigma)

    # The Gaussian process is a sum of these three components
    gp = gp_seasonal + gp_medium + gp_trend

    # Since the normal noise model and the GP are conjugates, we use `Marginal` with the `.marginal_likelihood` method
    y_ = gp.marginal_likelihood("y", X=t, y=y_n, noise=cov_noise)

    # this line calls an optimizer to find the MAP
    mp = pm.find_MAP(include_transformed=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='151' class='' max='151' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [151/151 00:37<00:00 logp = -818.99, ||grad|| = 0.009585]
#     </div>

# %%
sorted([name + ":" + str(mp[name]) for name in mp.keys() if not name.endswith("_")])
# Out:
# ['alpha:1.9984140517769151',
#  'eta_med:0.0011546400608626593',
#  'eta_noise:0.00029517094928918766',
#  'eta_per:0.10286732931580776',
#  'eta_trend:0.2662891453746301',
#  'l_med:1.3382104610780052',
#  'l_noise:0.2499706363285966',
#  'l_pdecay:119.97580739288593',
#  'l_psmooth :0.9700209963694129',
#  'l_trend:3.814172493123087',
#  'period:1.0053740065742587',
#  'sigma:0.9553050347480001']

# %%
# predict at a 15 day granularity
dates = pd.date_range(start="01/01/2010", end="31/12/2025", freq="1W")
tnew = dates_to_idx(dates.date)[:, None]

print("Predicting with gp ...")
mu, var = gp.predict(tnew, point=mp, diag=True)
mean_pred = mu * y_std + y_mean
var_pred = var * y_std ** 2

# make dataframe to store fit results
fit = pd.DataFrame(
    {"t": tnew.flatten(), "mu_total": mean_pred, "sd_total": np.sqrt(var_pred)},
    index=dates,
)

print("Predicting with gp_trend ...")
mu, var = gp_trend.predict(tnew, point=mp, given={"gp": gp, "X": t, "y": y, "noise": cov_noise}, diag=True)
fit = fit.assign(mu_trend=mu * y_std + y_mean, sd_trend=np.sqrt(var * y_std ** 2))

print("Predicting with gp_medium ...")
mu, var = gp_medium.predict(tnew, point=mp, given={"gp": gp, "X": t, "y": y, "noise": cov_noise}, diag=True)
fit = fit.assign(mu_medium=mu * y_std + y_mean, sd_medium=np.sqrt(var * y_std ** 2))

print("Predicting with gp_seasonal ...")
mu, var = gp_seasonal.predict(tnew, point=mp, given={"gp": gp, "X": t, "y": y, "noise": cov_noise}, diag=True)
fit = fit.assign(mu_seasonal=mu * y_std + y_mean, sd_seasonal=np.sqrt(var * y_std ** 2))
print("Done")
# Out:
# Predicting with gp ...
# Predicting with gp_trend ...
# Predicting with gp_medium ...
# Predicting with gp_seasonal ...
# Done

# %%
fit
# Out:
#                     t   mu_total   sd_total     mu_trend   sd_trend  \
# 2010-01-03   0.005479  37.900601   6.926111  1375.785213   7.527737
# 2010-01-10   0.024658  37.828676   6.888150  1377.000952   7.501737
# 2010-01-17   0.043836  37.795144   6.849461  1378.200656   7.475945
# 2010-01-24   0.063014  37.800047   6.810095  1379.384513   7.450363
# 2010-01-31   0.082192  37.842905   6.770117  1380.552714   7.424994
# ...               ...        ...        ...          ...        ...
# 2025-11-30  15.923288  58.912765  13.492536  1387.789362  13.133179
# 2025-12-07  15.942466  58.598190  13.516784  1379.561755  13.156438
# 2025-12-14  15.961644  58.303750  13.541304  1371.356815  13.179542
# 2025-12-21  15.980822  58.032719  13.566134  1363.174734  13.202490
# 2025-12-28  16.000000  57.788164  13.591305  1355.015701  13.225282
#
#             mu_medium  sd_medium  mu_seasonal  sd_seasonal
# 2010-01-03  53.031969   0.066454   452.945393     5.223732
# 2010-01-10  53.032039   0.066454   452.453315     5.223630
# 2010-01-17  53.032107   0.066454   454.157985     5.223567
# 2010-01-24  53.032173   0.066454   458.063534     5.223556
# 2010-01-31  53.032235   0.066454   464.144274     5.223603
# ...               ...        ...          ...          ...
# 2025-11-30  53.017093   0.066455   538.865442     5.228086
# 2025-12-07  53.016996   0.066455   523.117445     5.228194
# 2025-12-14  53.016899   0.066455   508.513108     5.228276
# 2025-12-21  53.016803   0.066455   495.239933     5.228325
# 2025-12-28  53.016708   0.066455   483.473543     5.228336
#
# [835 rows x 9 columns]

# %%
upper = fit.mu_total + 2 * fit.sd_total
lower = fit.mu_total - 2 * fit.sd_total
band_x = np.append(fit.t.values, fit.t.values[::-1])
band_y = np.append(lower, upper[::-1])

fig, ax = plt.subplots()
ax.plot(fit.t, fit.mu_total)
ax.fill_between(band_x, band_y, alpha=0.5)
sns.scatterplot(data=sdf, x='t', y='value', ax=ax)
# Out:
# <AxesSubplot:xlabel='t', ylabel='value'>

# %%
sns.lineplot(data=fit, y='mu_trend', x='t')
# Out:
# <AxesSubplot:xlabel='t', ylabel='mu_trend'>

# %%
sns.lineplot(data=fit, y='mu_seasonal', x='t')
# Out:
# <AxesSubplot:xlabel='t', ylabel='mu_seasonal'>

# %%
sns.lineplot(data=fit, y='mu_medium', x='t')
# Out:
# <AxesSubplot:xlabel='t', ylabel='mu_medium'>
